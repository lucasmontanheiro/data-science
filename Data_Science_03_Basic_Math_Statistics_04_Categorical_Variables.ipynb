# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasmontanheiro/colab/blob/main/Theory/Data_Science_03_Basic_Math_Statistics_04_Categorical_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basic Math and Statistics
#
# ###Segment 4 - Categorical Variables
#
# - Accepts only a limited and fixed number of values
# - Each observation is assigned to a specific subgroup
#
# Basic ways to describe categorical variables:
# 1. Counts
# 2. Variable Description
# 3. Grouping

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **The basics**

# %%
address = "https://raw.githubusercontent.com/lucasmontanheiro/db/main/exercises/mtcars.csv"
cars = pd.read_csv(address)

cars.columns = ["cars_names", "mpg", "cyl", "disp", "hp", "drat", "wt", "qsec", "vs", "am", "gear", "carb"]
cars.index = cars.cars_names
cars.head(15)
# Out:
#                             cars_names   mpg  cyl   disp   hp  drat     wt  \
# cars_names
# Mazda RX4                    Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag            Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                  Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive          Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# Valiant                        Valiant  18.1    6  225.0  105  2.76  3.460
# Duster 360                  Duster 360  14.3    8  360.0  245  3.21  3.570
# Merc 240D                    Merc 240D  24.4    4  146.7   62  3.69  3.190
# Merc 230                      Merc 230  22.8    4  140.8   95  3.92  3.150
# Merc 280                      Merc 280  19.2    6  167.6  123  3.92  3.440
# Merc 280C                    Merc 280C  17.8    6  167.6  123  3.92  3.440
# ...

# %%
carb = cars.carb
carb.value_counts()
# Out:
# 4    10
# 2    10
# 1     7
# 3     3
# 6     1
# 8     1
# Name: carb, dtype: int64

# %%
cars_cat = cars[["cyl", "vs", "am", "gear", "carb"]]
cars_cat.head()
# Out:
#                    cyl  vs  am  gear  carb
# cars_names
# Mazda RX4            6   0   1     4     4
# Mazda RX4 Wag        6   0   1     4     4
# Datsun 710           4   1   1     4     1
# Hornet 4 Drive       6   1   0     3     1
# Hornet Sportabout    8   0   0     3     2

# %%
gears_group = cars_cat.groupby("gear")
gears_group.describe()

# %% [markdown]
# **Transform variables to categorical data type**

# %%
cars["group"] = pd.Series(cars.gear, dtype="category")

# %%
cars["group"].dtypes
# Out:
# CategoricalDtype(categories=[3, 4, 5], ordered=False)

# %%
cars["group"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: group, dtype: int64

# %% [markdown]
# **Describing categorical data with crosstabs**

# %%
# A cross-tabulation of tow (or more) features
# By default, a crosstab table shows frequency for features

pd.crosstab(cars["am"], cars["gear"])
# Out:
# gear   3  4  5
# am
# 0     15  4  0
# 1      0  8  5
