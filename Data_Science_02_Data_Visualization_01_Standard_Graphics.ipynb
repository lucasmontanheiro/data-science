# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasmontanheiro/colab/blob/main/Theory/Data_Science_02_Data_Visualization_01_Standard_Graphics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Chapter 4 - Data Visualization
# ##Matplotlib
#
# Matplotlib GitHub Cheat Sheet : https://github.com/derekbanas/matplotlib

# %% [markdown]
# >[Chapter 4 - Data Visualization](#scrollTo=uKgNfqUPBnSW)
#
# >>[Matplotlib](#scrollTo=uKgNfqUPBnSW)
#
# >>>[Creating a line chart from a list object](#scrollTo=0bOHbZgTB9vK)
#
# >>>[Functional plot](#scrollTo=vREw05wyf7rV)
#
# >>>[Print Multiple Plots](#scrollTo=nFZs5M34hNMG)
#
# >>>[Using Figure Objects](#scrollTo=m0eL1ENziE83)
#
# >>>[Subplots](#scrollTo=Y0aLoCkjmett)
#
# >>>[DataFrames](#scrollTo=dlhiJyNlhTir)
#
# >>>>[Creating bar charts](#scrollTo=2_XiFiYdaaLg)
#
# >>>>[Creating a pie chart](#scrollTo=zbUsoAt-ayu5)
#
# >>>[Saving a plot](#scrollTo=F7rJ55Mha8KX)

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ###Creating a line chart from a list object
#
# **Plotting a line chart in matplotlib**

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

plt.plot(x,y)

# %% [markdown]
# ###Functional plot

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2
plt.plot(x_1, y_1)
plt.title("Days Squared Chart")
plt.xlabel("Days")
plt.ylabel("Days Squared")
# Out:
# Text(0, 0.5, 'Days Squared')

# %% [markdown]
# ###Print Multiple Plots

# %%
plt.subplot(1,2,1)
plt.plot(x_1,y_1,"r")
plt.subplot(1,2,2)
plt.plot(x_1,y_1,"b")

# %% [markdown]
# ###Using Figure Objects

# %%
# A figure is an object that contains all the plot elements
# It can contain many axes
# Define width & height in inches
# Dots per inch
fig_1 = plt.figure(figsize=(5,4), dpi=100)

# Adds axes with a left, bottom, width and height that ranges from 0 to 1
# which is the percent of the canvas you want to use
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9])

axes_1.set_xlabel("Days")
axes_1.set_ylabel("Days Squared")
axes_1.set_title("Days Squared Chart")
axes_1.plot(x_1,y_1,label="x/x2")
axes_1.plot(y_1,x_1,label="x2/x")
axes_1.legend(loc=0)

# Adding small chart inside
axes_2 = fig_1.add_axes([0.5,0.5,0.4,0.25])
axes_2.set_xlabel("Days")
axes_2.set_ylabel("Days Squared")
axes_2.set_title("Days Squared Chart")
axes_2.plot(x_1,y_1,"r")

# %% [markdown]
# ###Subplots

# %%
fig_2, axes_2 = plt.subplots(figsize=(8,4), nrows=1, ncols=3)
plt.tight_layout()

# Accessing plots by the index
axes_2[1].set_title("Plot 2")
axes_2[1].set_xlabel("X")
axes_2[1].set_ylabel("X Squared")
axes_2[1].plot(x_1,y_1)

# %% [markdown]
# ###DataFrames

# %%
address = "https://raw.githubusercontent.com/lucasmontanheiro/db/main/exercises/mtcars.csv"

cars = pd.read_csv(address)
cars.columns = ["car_names", "mpg", "cyl", "disp", "hp", "drat", "wt", "qsec", "vs", "am", "gear", "carb"]

mpg = cars["mpg"]

# %%
mpg.plot()

# %%
df = cars[["cyl","wt","mpg"]]
df.plot()

# %% [markdown]
# ####Creating bar charts
# **Creating a bar chart from a list**

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# **Creating bar charts from Pandas object**

# %%
mpg.plot(kind="bar")

# %%
mpg.plot(kind="barh")

# %% [markdown]
# ####Creating a pie chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ###Saving a plot

# %%
plt.pie(x)
plt.savefig("pie_chart.png")
plt.show()

# %%
# %pwd
# Out:
# '/content'
